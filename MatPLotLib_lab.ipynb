# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.plot([5,6,7,8],[1,3,3,4],'y*')
plt.ylabel('funny numbers')
plt.show()

# %%
t =np.arange(0,5,0.2)

# %%
plt.plot(t,t**2,'r--')

# %%
plt.plot(t,t**2,'r--',label="A")
plt.plot(t,t**3,'b--',label="B")
plt.legend(loc="upper left")

# %%
data={
    'a' : np.arange(1,51),
    'b' : np.random.randint(0,50,50),
    'c' : np.random.randn(50)
     }

# %%
plt.scatter(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-c2bb375a343c> in <module>
# ----> 1 plt.scatter(data)
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
plt.scatter(data['a'],data['b'])

# %%
plt.scatter(data['b'],data['c'])
